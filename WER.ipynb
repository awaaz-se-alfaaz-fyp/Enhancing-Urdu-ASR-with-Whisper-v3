# %%
# !pip install jiwer
from jiwer import wer, cer
import jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 24.0 MB/s eta 0:00:00
# ...

# %%
def calculate_wer(reference_path, hypothesis_path):

    #transcription
    with open(hypothesis_path, 'r', encoding='utf-8') as f:
        hypothesis = f.read().strip()

    #gold text
    with open(reference_path, 'r', encoding='utf-8') as f:
        reference = f.read().strip()

    word_error_rate = wer(reference, hypothesis)
    return word_error_rate

# %% [markdown]
# # YouTube evaluations

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/RamadanMoon Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/RamadanMoon.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 23.32%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/RamadanMoon Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/RamadanMoon.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 23.32%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/RamadanGas Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/RamadanGas.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 16.81%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/RamadanGas Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/RamadanGas.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 15.04%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/BullyingGPT Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Bullying.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 22.88%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/BullyingGPT Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Bullying.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 24.58%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/MobileTheft Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/MobileTheft.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 21.39%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/MobileTheft Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/MobileTheft.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 15.36%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/VehicleCollisionGPT.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/VehicleCollision.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 30.04%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/VehicleCollisionGPT.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/VehicleCollision.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 33.63%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/AfghanCricketGPT.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/AfghanCricket.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 21.84%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/AfghanCricketGPT.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/AfghanCricket.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 36.78%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PassengerGPT.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Passenger.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 31.08%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PassengerGPT.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Passenger.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 31.08%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/KarachiKings Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/KarachiKings.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 19.90%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/KarachiKings Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/KarachiKings.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 24.49%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Quetta Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Quetta.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 27.01%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Quetta Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Quetta.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 45.98%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PakVsInd Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/PakVsInd.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 17.24%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PakVsInd Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/PakvsInd.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 19.31%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Murree Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Murree.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 33.69%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Murree Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Murree.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 34.22%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PakvsInd2 Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/PakVsInd2.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 47.35%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PakvsInd2 Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/pakVsInd2.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 34.29%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/3Alleged Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/3Alleged.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 20.49%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/3Alleged Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/3Alleged.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 24.31%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PunjabGovt Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/PunjabGovt.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 49.54%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/PunjabGovt Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/PunjabGovt.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 36.64%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/BuildingCollapse Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/BuildingCollapse.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 25.18%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/BuildingCollapse Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/BuildingCollapse.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 25.18%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Women Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Women.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 13.31%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Women Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Women.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 17.96%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Inflation Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Inflation.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 17.95%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Inflation Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Inflation.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 23.44%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Kidney Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Kidney.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 27.11%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Kidney Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Kidney.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 30.12%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Sama Electricity Relief Key.txt"
Transcription = "/content/drive/MyDrive/FYP/Oct 24th - Youtube video evaluations/Vanilla Whisper Transcriptions/video1_transcription_output.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 16.59%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Sama Electricity Relief Key.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Electricity.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 53.71%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Sama PSL Multan Key.txt"
Transcription = "/content/drive/MyDrive/FYP/Oct 24th - Youtube video evaluations/Vanilla Whisper Transcriptions/video2_transcription_output.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 8.16%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Sama PSL Multan Key.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/PSL.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 13.66%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Traffic_Accident_Geo.txt"
Transcription = "/content/drive/MyDrive/FYP/Oct 24th - Youtube video evaluations/Vanilla Whisper Transcriptions/video3_transcription_output.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 32.01%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Traffic_Accident_Geo.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Traffic.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 30.22%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Sama FM Egypt Visit Key.txt"
Transcription = "/content/drive/MyDrive/FYP/Oct 24th - Youtube video evaluations/Vanilla Whisper Transcriptions/video4_transcription_output.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 15.97%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Sama FM Egypt Visit Key.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/FM Egypt.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 18.49%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Hamid Mir Imran Khan Key.txt"
Transcription = "/content/drive/MyDrive/FYP/Oct 24th - Youtube video evaluations/Vanilla Whisper Transcriptions/video5_transcription_output.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 8.54%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Hamid Mir Imran Khan Key.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Hamid Mir.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 9.76%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/GasTheft Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/GasTheft.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 20.13%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/GasTheft Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/GasTheft.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 23.32%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/ConstructionHalt Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/ConstructionHalt-2.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 17.37%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/ConstructionHalt Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/ConstructionHalt.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 19.49%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/SindhTax Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/SindhTax.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 33.19%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/SindhTax Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/SindhTax.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 39.82%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/RedLine_Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/RedLine.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 16.72%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/RedLine_Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/RedLine.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 20.50%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/CTD_Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/CTD.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 37.56%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/CTD_Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/CTD.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 40.38%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/11Deaths Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/11Deaths.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 29.15%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/11Deaths Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/11Death.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 27.41%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Petrol Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Large v3 Transcriptions/Petrol.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 26.64%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Petrol Gold.txt"
Transcription = "/content/drive/MyDrive/FYP/YouTube Dataset/Whisper Turbo v3 Transcriptions/Petrol.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 64.95%

# %% [markdown]
# # SLM evals

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/3Alleged Gold.txt"
Transcription = "/content/3Alleged Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 53.47%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/11Deaths Gold.txt"
Transcription = "/content/11Deaths Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 70.85%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/AfghanCricketGPT.txt"
Transcription = "/content/AfghanCricketGPT.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 48.66%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/BuildingCollapse Gold.txt"
Transcription = "/content/BuildingCollapse Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 64.37%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/BullyingGPT Gold.txt"
Transcription = "/content/BullyingGPT Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 42.37%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/ConstructionHalt Gold.txt"
Transcription = "/content/ConstructionHalt_Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 41.10%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/CTD_Gold.txt"
Transcription = "/content/CTD_Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 39.44%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/GasTheft Gold.txt"
Transcription = "/content/GasTheft_Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 55.91%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Inflation Gold.txt"
Transcription = "/content/Inflation Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 52.38%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/KarachiKings Gold.txt"
Transcription = "/content/KarachiKings Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 60.71%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/Kidney Gold.txt"
Transcription = "/content/Kidney Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 59.64%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/MobileTheft Gold.txt"
Transcription = "/content/MobileTheft Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
# Out:
# Word Error Rate (WER): 51.81%

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/MobileTheft Gold.txt"
Transcription = "/content/MobileTheft Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")

# %%
Gold = "/content/drive/MyDrive/FYP/YouTube Dataset/Gold Transcriptions/MobileTheft Gold.txt"
Transcription = "/content/MobileTheft Gold.txt"

wer_result = calculate_wer(Gold, Transcription)
print(f"Word Error Rate (WER): {wer_result:.2%}")
